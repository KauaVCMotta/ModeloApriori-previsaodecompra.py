# %% [markdown]
# # Aprendizado por Regra de Associação - Modelo a Apriori

# %% [markdown]
# ## Instalando a biblioteca Apyori

# %%
# !pip install apyori #Se X, então Y", indicando que quando um conjunto de itens X é encontrado em uma transação, é provável que o conjunto de itens Y também esteja presente.
# Out:
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5956 sha256=18223abd0a9b959be87d82a5ff6fd64ea104714956e1c5385ced893df33eb915
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %% [markdown]
# ## Importando as bibliotecas

# %%
import numpy as np
import pandas as pd
from apyori import apriori

# %% [markdown]
# ## Preprocessamento dos dados

# %%
dataset = pd.read_csv('dados.csv', header = None)

#transformando o dataframe em array
transacoes = []
for i in range(dataset.shape[0]):
  transacoes.append([str(dataset.values[i,j]) for j in range(dataset.shape[1])])

# %%
dataset.shape
# Out:
# (241, 6)

# %%
transacoes
# Out:
# [['Janelas de alumínio',
#   ' Vidros',
#   ' Silicone',
#   'argamassa',
#   'cal',
#   'cimento'],
#  ['Tintas para parede',
#   ' Pincéis e rolos de pintura',
#   ' Espátulas',
#   'nan',
#   'nan',
#   'nan'],
#  ['Telhas de cerâmica', ' Cimento', ' Areia', 'nan', 'nan', 'nan'],
#  ['Torneiras e registros', ' Tubos de PVC', 'nan', 'nan', 'nan', 'nan'],
#  ['Tuminárias', ' Fios elétricos', ' Disjuntores', 'nan', 'nan', 'nan'],
#  ['Tijolos', ' Argamassa', ' Serrote', 'nan', 'nan', 'nan'],
#  ['Pisos laminados',
#   ' Cola para pisos',
#   ' Régua de medição',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chuveiro elétrico',
#   ' Cabos para instalação elétrica',
#   ' Interruptores',
#   'nan',
#   'nan',
#   'nan'],
#  ['Ferramentasrramentas de jardinagem',
#   ' Vasos de plantas',
#   ' Substrato',
#   'nan',
#   'nan',
#   'nan'],
#  ['Pias de banheiro',
#   ' Armários de banheiro',
#   ' Torneiras',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta para piso',
#   ' Rolo de pintura para piso',
#   ' Massa niveladora',
#   'nan',
#   'nan',
#   'nan'],
#  ['Pisos cerâmicos', ' Rejunte', ' Espaçadores', 'nan', 'nan', 'nan'],
#  ['Lajes pré-moldadas', ' Vergalhões', ' Arame recozido', 'nan', 'nan', 'nan'],
#  ['Portas de madeira', ' Dobradiças', ' Fechaduras', 'nan', 'nan', 'nan'],
#  ['Janelas de alumínio', ' Vidros', ' Silicone', 'nan', 'nan', 'nan'],
#  ['Gesso em pó', ' Placas de gesso', ' Perfis metálicos', 'nan', 'nan', 'nan'],
#  ['Parafusos', ' Buchas', ' Serra copo', 'nan', 'nan', 'nan'],
#  ['Pintura externa', ' Impermeabilizante', ' Escadas', 'nan', 'nan', 'nan'],
#  ['Máquina de solda',
#   ' Eletrodos',
#   ' Luvas de segurança',
#   'nan',
#   'nan',
#   'nan'],
#  ['Portões de garagem', ' Trilhos', ' Automatizadores', 'nan', 'nan', 'nan'],
#  ['Telas de proteção',
#   ' Tintas para grade',
#   ' Arames farpados',
#   'nan',
#   'nan',
#   'nan'],
#  ['Luminárias', ' Fios elétricos', ' Disjuntores', 'nan', 'nan', 'nan'],
#  ['Ferramentas de jardinagem',
#   ' Vasos de plantas',
#   ' Substrato',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tijolos', ' Cimento', ' Areia', 'nan', 'nan', 'nan'],
#  ['Revestimento cerâmico',
#   ' Argamassa para revestimento',
#   ' Telhas de cerâmica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Telhas de fibrocimento', ' Cal', ' Prego', 'nan', 'nan', 'nan'],
#  ['Bucha', ' Martelo', ' Chave de fenda', 'nan', 'nan', 'nan'],
#  ['Serra circular', ' Tinta látex', ' Pincel de pintura', 'nan', 'nan', 'nan'],
#  ['Massa corrida',
#   ' Espátula de aplicação',
#   ' Lixa de parede',
#   'nan',
#   'nan',
#   'nan'],
#  ['Argamassa',
#   ' Revestimento cerâmico',
#   ' Argamassa para revestimento',
#   'nan',
#   'nan',
#   'nan'],
#  ['Telhas de cerâmica',
#   ' Telhas de fibrocimento',
#   ' Cal',
#   'nan',
#   'nan',
#   'nan'],
#  ['Prego', ' Parafuso', ' Bucha', 'nan', 'nan', 'nan'],
#  ['Martelo', ' Chave de fenda', ' Chave Philips', 'nan', 'nan', 'nan'],
#  ['Serra circular', ' Esquadro', ' Tinta látex', 'nan', 'nan', 'nan'],
#  ['Pincel de pintura',
#   ' Rolo de pintura',
#   ' Massa corrida',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cimento', ' Areia', ' Argamassa', 'nan', 'nan', 'nan'],
#  ['Tijolos', ' Cimento', ' Areia', ' Argamassa', 'nan', 'nan'],
#  ['Telhas de fibrocimento', ' Cal', ' Prego', ' Parafuso', 'nan', 'nan'],
#  ['Bucha', ' Martelo', ' Chave de fenda', ' Chave Philips', 'nan', 'nan'],
#  ['Tijolos', ' Cimento', ' Argamassa', 'nan', 'nan', 'nan'],
#  ['Cal',
#   ' Telhas de cerâmica',
#   ' Argamassa para revestimento',
#   'nan',
#   'nan',
#   'nan'],
#  ['Parafuso', ' Bucha', ' Martelo', 'nan', 'nan', 'nan'],
#  ['Chave Philips', ' Serra circular', ' Esquadro', 'nan', 'nan', 'nan'],
#  ['Rolo de pintura', ' Tinta látex', ' Massa corrida', 'nan', 'nan', 'nan'],
#  ['Telhas de fibrocimento',
#   ' Argamassa para revestimento',
#   ' Cal',
#   'nan',
#   'nan',
#   'nan'],
#  ['Bucha', ' Prego', ' Chave de fenda', 'nan', 'nan', 'nan'],
#  ['Pincel de pintura', ' Tinta látex', ' Serra circular', 'nan', 'nan', 'nan'],
#  ['Lixa de parede',
#   ' Espátula de aplicação',
#   ' Massa corrida',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cimento', ' Argamassa', ' Tijolos', 'nan', 'nan', 'nan'],
#  ['Telhas de cerâmica',
#   ' Revestimento cerâmico',
#   ' Argamassa para revestimento',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cal', ' Parafuso', ' Telhas de fibrocimento', 'nan', 'nan', 'nan'],
#  ['Martelo', ' Bucha', ' Chave Philips', 'nan', 'nan', 'nan'],
#  ['Lixa de parede',
#   ' Massa corrida',
#   ' Espátula de aplicação',
#   'nan',
#   'nan',
#   'nan'],
#  ['Argamassa', ' Areia', ' Tijolos', 'nan', 'nan', 'nan'],
#  ['Revestimento cerâmico',
#   ' Telhas de cerâmica',
#   ' Argamassa para revestimento',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chave de fenda', ' Bucha', ' Martelo', 'nan', 'nan', 'nan'],
#  ['Espátula de aplicação',
#   ' Massa corrida',
#   ' Lixa de parede',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cal',
#   ' Argamassa para revestimento',
#   ' Telhas de cerâmica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Parafuso', ' Martelo', ' Bucha', 'nan', 'nan', 'nan'],
#  ['Chave Philips', ' Esquadro', ' Serra circular', 'nan', 'nan', 'nan'],
#  ['Rolo de pintura', ' Massa corrida', ' Tinta látex', 'nan', 'nan', 'nan'],
#  ['Argamassa', ' Areia', ' Cimento', 'nan', 'nan', 'nan'],
#  ['Cal', ' Telhas de fibrocimento', ' Prego', 'nan', 'nan', 'nan'],
#  ['Chave de fenda', ' Martelo', ' Bucha', 'nan', 'nan', 'nan'],
#  ['Pincel de pintura', ' Serra circular', ' Tinta látex', 'nan', 'nan', 'nan'],
#  ['Cal', ' Prego', ' Telhas de fibrocimento', 'nan', 'nan', 'nan'],
#  ['Serra circular', ' Esquadro', ' Pincel de pintura', 'nan', 'nan', 'nan'],
#  ['Argamassa', ' Tijolos', ' Areia', 'nan', 'nan', 'nan'],
#  ['Telhas de cerâmica',
#   ' Argamassa para revestimento',
#   ' Revestimento cerâmico',
#   'nan',
#   'nan',
#   'nan'],
#  ['Telhas de fibrocimento', ' Parafuso', ' Cal', 'nan', 'nan', 'nan'],
#  ['Bucha', ' Chave Philips', ' Martelo', 'nan', 'nan', 'nan'],
#  ['Tinta látex', ' Serra circular', ' Pincel de pintura', 'nan', 'nan', 'nan'],
#  ['Tinta acrílica',
#   ' Espátula de aço',
#   ' Rolo de pintura',
#   'nan',
#   'nan',
#   'nan'],
#  ['Telhas de fibrocimento',
#   ' Massa para vedação',
#   ' Lixa de madeira',
#   'nan',
#   'nan',
#   'nan'],
#  ['Argamassa colante',
#   ' Rejunte para azulejo',
#   ' Desempenadeira de aço',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta esmalte',
#   ' Pincel de cerdas',
#   ' Rolo de espuma',
#   'nan',
#   'nan',
#   'nan'],
#  ['Parafuso', ' Broca de aço rápido', ' Bucha de nylon', 'nan', 'nan', 'nan'],
#  ["Lixa d'água",
#   ' Verniz para madeira',
#   ' Pincel de cabo longo',
#   'nan',
#   'nan',
#   'nan'],
#  ['Saco de cimento',
#   ' Areia lavada',
#   ' Tijolos refratários',
#   'nan',
#   'nan',
#   'nan'],
#  ['Martelo', ' Chave de grifo', ' Alicate universal', 'nan', 'nan', 'nan'],
#  ['Tinta spray',
#   ' Máscara de proteção',
#   ' Luvas de segurança',
#   'nan',
#   'nan',
#   'nan'],
#  ['Torneira',
#   ' Chuveiro elétrico',
#   ' Vedante de silicone',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cola para madeira',
#   ' Sargentos de aperto',
#   ' Serrote',
#   'nan',
#   'nan',
#   'nan'],
#  ['Interruptor', ' Tomada elétrica', ' Fio elétrico', 'nan', 'nan', 'nan'],
#  ['Vaso sanitário',
#   ' Assento sanitário',
#   ' Caixa acoplada',
#   'nan',
#   'nan',
#   'nan'],
#  ['Lâmpada LED', ' Soquete', ' Fita isolante', 'nan', 'nan', 'nan'],
#  ['Espelho para banheiro',
#   ' Armário de parede',
#   ' Porta-toalhas',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta epóxi', ' Catalisador', ' Rolo texturizado', 'nan', 'nan', 'nan'],
#  ['Saco de argamassa',
#   ' Desempenadeira de PVC',
#   ' Nível a laser',
#   'nan',
#   'nan',
#   'nan'],
#  ['Janela de alumínio',
#   ' Trinco',
#   ' Silicone para vidro',
#   'nan',
#   'nan',
#   'nan'],
#  ['Fio de cobre', ' Disjuntor', ' Caixa de distribuição', 'nan', 'nan', 'nan'],
#  ['Prateleira', ' Suportes', ' Buchas para parede', 'nan', 'nan', 'nan'],
#  ['Chave de fenda', ' Caixa de ferramentas', ' Trena', 'nan', 'nan', 'nan'],
#  ['Serra circular',
#   ' Martelo de borracha',
#   ' Parafuso de fixação',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta spray',
#   ' Pincel de cerdas macias',
#   ' Rolo de espuma',
#   'nan',
#   'nan',
#   'nan'],
#  ['Broca para concreto',
#   ' Trena a laser',
#   ' Sugador de solda',
#   'nan',
#   'nan',
#   'nan'],
#  ['Lâmina de serra tico-tico',
#   ' Alicate de corte',
#   ' Estilete',
#   'nan',
#   'nan',
#   'nan'],
#  ['Martelo de unha',
#   ' Alicate de pressão',
#   ' Tinta esmalte',
#   'nan',
#   'nan',
#   'nan'],
#  ['Fita adesiva',
#   ' Parafuso autoatarraxante',
#   ' Kit de chaves Allen',
#   'nan',
#   'nan',
#   'nan'],
#  ['Furadeira elétrica',
#   ' Chave inglesa',
#   ' Bucha de fixação',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta acrílica', " Lixa d'água", ' Espátula de aço', 'nan', 'nan', 'nan'],
#  ['Martelo de pena', ' Chave de boca', ' Disco de corte', 'nan', 'nan', 'nan'],
#  ['Pistola de cola quente',
#   ' Alicate de bico',
#   ' Nível de bolha',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serra de fita',
#   ' Chave de grifo',
#   ' Abraçadeira metálica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Trena retrátil',
#   ' Chave de teste',
#   ' Lixa para madeira',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta epóxi',
#   ' Espelho decorativo',
#   ' Broca para metal',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cola instantânea', ' Serra copo', ' Desengripante', 'nan', 'nan', 'nan'],
#  ['Fita isolante',
#   ' Chave de catraca',
#   ' Óculos de proteção',
#   'nan',
#   'nan',
#   'nan'],
#  ['Alicate universal',
#   ' Rolo de pintura texturizado',
#   ' Grampo de marceneiro',
#   'nan',
#   'nan',
#   'nan'],
#  ['Lâmpada fluorescente',
#   ' Estilete de precisão',
#   ' Desengordurante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Sugador de solda',
#   ' Alicate de crimpagem',
#   ' Luvas de segurança',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta para piso',
#   ' Chave de fenda elétrica',
#   ' Kit de chaves de precisão',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serra mármore',
#   ' Desempenadeira de aço',
#   ' Massa para calafetar',
#   'nan',
#   'nan',
#   'nan'],
#  ['Pistola de pintura',
#   ' Pincel para acabamento',
#   ' Parafuso sextavado',
#   'nan',
#   'nan',
#   'nan'],
#  ['Broca para madeira',
#   ' Serrote de costas',
#   ' Nível a laser',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta lousa', ' Régua de aço', ' Fita métrica', 'nan', 'nan', 'nan'],
#  ['Chave ajustável',
#   ' Fita adesiva dupla face',
#   ' Martelo de bola',
#   'nan',
#   'nan',
#   'nan'],
#  ['Lâmpada incandescente',
#   ' Chave de grifo ajustável',
#   ' Silicone para vedação',
#   'nan',
#   'nan',
#   'nan'],
#  ['Rolo de lã de carneiro',
#   ' Tinta para azulejo',
#   ' Lápis de carpinteiro',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chave de impacto', ' Estopa', ' Prego de aço', 'nan', 'nan', 'nan'],
#  ['Tinta antimofo',
#   ' Parafuso cabeça chata',
#   ' Maçarico a gás',
#   'nan',
#   'nan',
#   'nan'],
#  ['Fita VHB',
#   ' Chave de cano',
#   ' Fita zebrada de segurança',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serra sabre', ' Espátula de PVC', ' Solda em bastão', 'nan', 'nan', 'nan'],
#  ['Pistola de cola quente',
#   ' Lâmina de estilete',
#   ' Bateria de furadeira',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta magnética',
#   ' Pincel de cabo longo',
#   ' Dobradiça',
#   'nan',
#   'nan',
#   'nan'],
#  ['Rolo para pintura de textura',
#   ' Broca helicoidal',
#   ' Lubrificante multiuso',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chave de boca',
#   ' Serrote japonês',
#   ' Fita isolante de alta tensão',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serra de arco',
#   ' Alicate amperímetro',
#   ' Saco de lixo',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta emborrachada',
#   ' Alicate corte diagonal',
#   ' Espuma expansiva',
#   'nan',
#   'nan',
#   'nan'],
#  ['Cola de contato',
#   ' Serra tico-tico',
#   ' Pincel de espuma',
#   'nan',
#   'nan',
#   'nan'],
#  ['Fita crepe', ' Chave teste', ' Régua de alumínio', 'nan', 'nan', 'nan'],
#  ['Tinta para piso epóxi',
#   ' Lápis de pedreiro',
#   ' Chave Philips',
#   'nan',
#   'nan',
#   'nan'],
#  ['Lâmina de serra circular',
#   ' Desempenadeira de PVC',
#   ' Parafuso autoatarraxante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serra circular de bancada',
#   ' Alicates de pressão',
#   ' Grampeador manual',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta fosca', ' Estilete retrátil', ' Tinta metálica', 'nan', 'nan', 'nan'],
#  ['Fita de demarcação',
#   ' Chave ajustável de corrente',
#   ' Nível de alumínio',
#   'nan',
#   'nan',
#   'nan'],
#  ['Martelo de pedreiro',
#   ' Lixa para ferro',
#   ' Máscara respiratória',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta spray cromada',
#   ' Lupa de bancada',
#   ' Parafuso olhal',
#   'nan',
#   'nan',
#   'nan'],
#  ['Broca de vídea',
#   ' Serrote de costas',
#   ' Lâmpada de emergência',
#   'nan',
#   'nan',
#   'nan'],
#  ['Pistola de pintura airless',
#   ' Pincel para gesso',
#   ' Parafuso auto brocante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tinta emborrachada impermeabilizante',
#   ' Chave de fenda isolada',
#   ' Lixa para drywall',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chave canhão',
#   ' Serra de copo diamantada',
#   ' Rolo de pintura anti-gota',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chavedefenda', 'Martelodeborracha', 'Serracircular', 'nan', 'nan', 'nan'],
#  ['Tintaspray', 'Rolodeespuma', 'Brocaparaconcreto', 'nan', 'nan', 'nan'],
#  ['Alicatedecorte', 'Estilete', 'Martelodeunha', 'nan', 'nan', 'nan'],
#  ['Alicatedepressão', 'Tintaesmalte', 'Fitaadesiva', 'nan', 'nan', 'nan'],
#  ['Parafusoautoatarraxante',
#   'KitdechavesAllen',
#   'Furadeiraelétrica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chaveinglesa', 'Buchadefixação', 'Tintaacrílica', 'nan', 'nan', 'nan'],
#  ["Lixad'água", 'Espátuladeaço', 'Martelodepena', 'nan', 'nan', 'nan'],
#  ['Chavedeboca', 'Discodecorte', 'Pistoladecolaquente', 'nan', 'nan', 'nan'],
#  ['Alicatedebico', 'Níveldebolha', 'Serradefita', 'nan', 'nan', 'nan'],
#  ['Chavedegrifo', 'Abraçadeirametálica', 'Trenaretrátil', 'nan', 'nan', 'nan'],
#  ['Chavedeteste', 'Trenaretrátil', 'Abraçadeirametálica', 'nan', 'nan', 'nan'],
#  ['Serradefita', 'Níveldebolha', 'Alicatedebico', 'nan', 'nan', 'nan'],
#  ['Pistoladecolaquente', 'Discodecorte', 'Chavedeboca', 'nan', 'nan', 'nan'],
#  ['Martelodepena', 'Espátuladeaço', "Lixad'água", 'nan', 'nan', 'nan'],
#  ['Tintaacrílica', 'Buchadefixação', 'Chaveinglesa', 'nan', 'nan', 'nan'],
#  ['Furadeiraelétrica',
#   'KitdechavesAllen',
#   'Parafusoautoatarraxante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Fitaadesiva', 'Tintaesmalte', 'Alicatedepressão', 'nan', 'nan', 'nan'],
#  ['Martelodeunha', 'Estilete', 'Alicatedecorte', 'nan', 'nan', 'nan'],
#  ['Brocaparaconcreto', 'Rolodeespuma', 'Tintaspray', 'nan', 'nan', 'nan'],
#  ['Serracircular', 'Martelodeborracha', 'Chavedefenda', 'nan', 'nan', 'nan'],
#  ['Abraçadeirametálica', 'Trenaretrátil', 'Chavedeteste', 'nan', 'nan', 'nan'],
#  ['Serradefita', 'Alicatedebico', 'Chavedegrifo', 'nan', 'nan', 'nan'],
#  ['Pistoladecolaquente', 'Chavedeboca', 'Níveldebolha', 'nan', 'nan', 'nan'],
#  ['Espátuladeaço', 'Discodecorte', 'Alicatedebico', 'nan', 'nan', 'nan'],
#  ['Chavedeteste', 'Martelodepena', "Lixad'água", 'nan', 'nan', 'nan'],
#  ['Chaveinglesa', 'Tintaacrílica', 'Abraçadeirametálica', 'nan', 'nan', 'nan'],
#  ['Trenaretrátil',
#   'KitdechavesAllen',
#   'Furadeiraelétrica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Parafusoautoatarraxante',
#   'Fitaadesiva',
#   'Martelodeunha',
#   'nan',
#   'nan',
#   'nan'],
#  ['Alicatedecorte', 'Estilete', 'Alicatedepressão', 'nan', 'nan', 'nan'],
#  ['Tintaesmalte', 'Rolodeespuma', 'Brocaparaconcreto', 'nan', 'nan', 'nan'],
#  ['Chavedegrifo', 'Níveldebolha', 'Alicatedebico', 'nan', 'nan', 'nan'],
#  ['Pistoladecolaquente', 'Chavedeboca', 'Discodecorte', 'nan', 'nan', 'nan'],
#  ['Espátuladeaço', "Lixad'água", 'Chavedeteste', 'nan', 'nan', 'nan'],
#  ['Alicatedepressão', 'Martelodepena', 'Tintaacrílica', 'nan', 'nan', 'nan'],
#  ['Abraçadeirametálica',
#   'Trenaretrátil',
#   'Furadeiraelétrica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tintaspray',
#   'Rolodeespuma',
#   'Parafusoautoatarraxante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chavedefenda', 'Serracircular', 'Chaveinglesa', 'nan', 'nan', 'nan'],
#  ['Chavedeboca', 'Buchadefixação', 'Tintaesmalte', 'nan', 'nan', 'nan'],
#  ['Brocaparaconcreto', 'KitdechavesAllen', 'Fitaadesiva', 'nan', 'nan', 'nan'],
#  ['Chavedegrifo', 'Pistoladecolaquente', 'Discodecorte', 'nan', 'nan', 'nan'],
#  ['Espátuladeaço', "Lixad'água", 'Martelodepena', 'nan', 'nan', 'nan'],
#  ['Tintaacrílica', 'Abraçadeirametálica', 'Chavedeteste', 'nan', 'nan', 'nan'],
#  ['Furadeiraelétrica', 'Trenaretrátil', 'Chaveinglesa', 'nan', 'nan', 'nan'],
#  ['Parafusoautoatarraxante',
#   'Fitaadesiva',
#   'Alicatedepressão',
#   'nan',
#   'nan',
#   'nan'],
#  ['Serracircular', 'Rolodeespuma', 'Tintaspray', 'nan', 'nan', 'nan'],
#  ['Chavedefenda',
#   'Martelodeborracha',
#   'Brocaparaconcreto',
#   'nan',
#   'nan',
#   'nan'],
#  ['Tintaesmalte', 'Buchadefixação', 'Chavedeboca', 'nan', 'nan', 'nan'],
#  ['Discodecorte', 'Pistoladecolaquente', 'Níveldebolha', 'nan', 'nan', 'nan'],
#  ['Alicatedebico', "Lixad'água", 'Espátuladeaço', 'nan', 'nan', 'nan'],
#  ['Chavedeteste', 'Martelodepena', 'Furadeiraelétrica', 'nan', 'nan', 'nan'],
#  ['Trenaretrátil',
#   'Abraçadeirametálica',
#   'KitdechavesAllen',
#   'nan',
#   'nan',
#   'nan'],
#  ['Alicatedepressão',
#   'Serradefita',
#   'Parafusoautoatarraxante',
#   'nan',
#   'nan',
#   'nan'],
#  ['Estilete', 'Chavedefenda', 'Tintaacrílica', 'nan', 'nan', 'nan'],
#  ['Chaveinglesa', 'Rolodeespuma', 'Martelodeunha', 'nan', 'nan', 'nan'],
#  ['Fitaadesiva', 'Brocaparaconcreto', 'Alicatedecorte', 'nan', 'nan', 'nan'],
#  ['Martelodeborracha', 'Serracircular', 'Tintaspray', 'nan', 'nan', 'nan'],
#  ['Níveldebolha', 'Estilete', 'Chavedegrifo', 'nan', 'nan', 'nan'],
#  ['Alicatedebico', 'Chavedeboca', 'Pistoladecolaquente', 'nan', 'nan', 'nan'],
#  ['Discodecorte', "Lixad'água", 'Espátuladeaço', 'nan', 'nan', 'nan'],
#  ['Tintaacrílica', 'Alicatedepressão', 'Chavedeteste', 'nan', 'nan', 'nan'],
#  ['Martelodepena', 'Furadeiraelétrica', 'Trenaretrátil', 'nan', 'nan', 'nan'],
#  ['KitdechavesAllen',
#   'Parafusoautoatarraxante',
#   'Fitaadesiva',
#   'nan',
#   'nan',
#   'nan'],
#  ['Chaveinglesa', 'Brocaparaconcreto', 'Martelodeunha', 'nan', 'nan', 'nan'],
#  ['Rolodeespuma', 'Tintaspray', 'Chavedefenda', 'nan', 'nan', 'nan'],
#  ['Serracircular', 'Buchadefixação', 'Alicatedecorte', 'nan', 'nan', 'nan'],
#  ['Alicatedebico', 'Estilete', 'Níveldebolha', 'nan', 'nan', 'nan'],
#  ['Chavedegrifo', 'Discodecorte', 'Pistoladecolaquente', 'nan', 'nan', 'nan'],
#  ['Espátuladeaço', "Lixad'água", 'Chavedeboca', 'nan', 'nan', 'nan'],
#  ['Martelodepena',
#   'Tintaacrílica',
#   'Abraçadeirametálica',
#   'nan',
#   'nan',
#   'nan'],
#  ['Furadeiraelétrica', 'Trenaretrátil', 'Chavedeteste', 'nan', 'nan', 'nan'],
#  ['Alicatedepressão', 'KitdechavesAllen', 'Serradefita', 'nan', 'nan', 'nan'],
#  ['Parafusoautoatarraxante',
#   'Fitaadesiva',
#   'Chaveinglesa',
#   'nan',
#   'nan',
#   'nan'],
#  ['Martelodeunha', 'Brocaparaconcreto', 'Estilete', 'nan', 'nan', 'nan'],
#  ['Tintaspray', 'Rolodeespuma', 'Chavedefenda', 'nan', 'nan', 'nan'],
#  ['Alicatedecorte', 'Buchadefixação', 'Serracircular', 'nan', 'nan', 'nan'],
#  ['Níveldebolha', 'Alicatedebico', 'Chavedegrifo', 'nan', 'nan', 'nan'],
#  ['Parafuso', ' Bucha', ' Trena', ' Serrote', 'nan', 'nan'],
#  ['Tinta esmalte',
#   ' Pincel de cerdas',
#   ' Bandeja para pintura',
#   ' Espátula',
#   'nan',
#   'nan'],
#  ['Telhas de cerâmica', ' Calha', ' Ralo', ' Silicone', 'nan', 'nan'],
#  ['Broca', ' Martelo', ' Serrote', ' Nível a laser', 'nan', 'nan'],
#  ['Prego', ' Arame', ' Martelo', ' Serrote', 'nan', 'nan'],
#  ['Cimento', ' Areia', ' Tijolos', ' Vergalhão', 'nan', 'nan'],
#  ['Tinta acrílica',
#   ' Rolo de pintura',
#   ' Pincel de cerdas',
#   ' Fita crepe',
#   'nan',
#   'nan'],
#  ['Chave de fenda', ' Alicate', ' Martelo', ' Trena', 'nan', 'nan'],
#  ['Porcelanato', ' Argamassa', ' Rejunte', ' Nivelador de piso', 'nan', 'nan'],
#  ['Lâmpadas', ' Fios elétricos', ' Interruptor', ' Tomada', 'nan', 'nan'],
#  ['Torneira',
#   ' Sifão',
#   ' Válvula de descarga',
#   ' Ducha higiênica',
#   'nan',
#   'nan'],
#  ['Tinta esmalte',
#   ' Rolo de pintura',
#   ' Pincel de cerdas',
#   ' Espátula',
#   'nan',
#   'nan'],
#  ['Pisos',
#   ' Revestimentos',
#   ' Adesivo para azulejo',
#   ' Espátula',
#   'nan',
#   'nan'],
#  ['Tubos de PVC',
#   ' Conexões',
#   ' Sifão de pia',
#   ' Válvula de descarga',
#   'nan',
#   'nan'],
#  ['Tintas', ' Pincel', ' Rolo de pintura', ' Lixa de parede', 'nan', 'nan'],
#  ['Telhas de fibrocimento',
#   ' Cumeeiras',
#   ' Manta térmica',
#   ' Parafusos para telhas',
#   'nan',
#   'nan'],
#  ['Chuveiro', ' Fio elétrico', ' Disjuntor', ' Tomada', 'nan', 'nan'],
#  ['Luminárias',
#   ' Lâmpadas LED',
#   ' Interruptor',
#   ' Extensão elétrica',
#   'nan',
#   'nan'],
#  ['Torneira',
#   ' Válvula de escoamento',
#   ' Sifão de lavatório',
#   ' Misturador de água',
#   'nan',
#   'nan'],
#  ['Argamassa colante',
#   ' Rejunte para porcelanato',
#   ' Espátula dentada',
#   ' Nivelador de piso',
#   'nan',
#   'nan'],
#  ['Interruptor de luz',
#   ' Tomada',
#   ' Fio elétrico',
#   ' Disjuntor',
#   'nan',
#   'nan'],
#  ['Pisos laminados',
#   ' Rodapés',
#   ' Manta acústica',
#   ' Cola para piso',
#   'nan',
#   'nan'],
#  ['Tinta spray',
#   ' Pincel de cerdas macias',
#   ' Fita adesiva',
#   ' Máscara de proteção',
#   'nan',
#   'nan']]

# %% [markdown]
# ## Treinando o modelo Apriori

# %%
regra = apriori (transactions = transacoes, min_support = 0.003, min_confidence = 0.2, min_lift = 2, min_length = 2, max_length = 2)

# %% [markdown]
# ## Visualizando os resultados

# %% [markdown]
# ### Resultados diretamente da saída do treinamento

# %%
resultado = list(regra)

# %%
resultado
# Out:
# [RelationRecord(items=frozenset({' Abraçadeira metálica', ' Chave de grifo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Abraçadeira metálica'}), items_add=frozenset({' Chave de grifo'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({' Chave de grifo'}), items_add=frozenset({' Abraçadeira metálica'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({'Serra de fita', ' Abraçadeira metálica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Abraçadeira metálica'}), items_add=frozenset({'Serra de fita'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Serra de fita'}), items_add=frozenset({' Abraçadeira metálica'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Adesivo para azulejo', ' Espátula'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Adesivo para azulejo'}), items_add=frozenset({' Espátula'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Espátula'}), items_add=frozenset({' Adesivo para azulejo'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Adesivo para azulejo', ' Revestimentos'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Adesivo para azulejo'}), items_add=frozenset({' Revestimentos'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Revestimentos'}), items_add=frozenset({' Adesivo para azulejo'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Adesivo para azulejo', 'Pisos'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Adesivo para azulejo'}), items_add=frozenset({'Pisos'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Pisos'}), items_add=frozenset({' Adesivo para azulejo'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate', ' Martelo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate'}), items_add=frozenset({' Martelo'}), confidence=1.0, lift=24.1)]),
#  RelationRecord(items=frozenset({' Alicate', ' Trena'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate'}), items_add=frozenset({' Trena'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Trena'}), items_add=frozenset({' Alicate'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Alicate', 'Chave de fenda'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate'}), items_add=frozenset({'Chave de fenda'}), confidence=1.0, lift=60.25), OrderedStatistic(items_base=frozenset({'Chave de fenda'}), items_add=frozenset({' Alicate'}), confidence=0.25, lift=60.25)]),
#  RelationRecord(items=frozenset({' Alicate amperímetro', ' Saco de lixo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate amperímetro'}), items_add=frozenset({' Saco de lixo'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Saco de lixo'}), items_add=frozenset({' Alicate amperímetro'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Serra de arco', ' Alicate amperímetro'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate amperímetro'}), items_add=frozenset({'Serra de arco'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Serra de arco'}), items_add=frozenset({' Alicate amperímetro'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Espuma expansiva', ' Alicate corte diagonal'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate corte diagonal'}), items_add=frozenset({' Espuma expansiva'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Espuma expansiva'}), items_add=frozenset({' Alicate corte diagonal'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Tinta emborrachada', ' Alicate corte diagonal'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate corte diagonal'}), items_add=frozenset({'Tinta emborrachada'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Tinta emborrachada'}), items_add=frozenset({' Alicate corte diagonal'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de bico', ' Nível de bolha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de bico'}), items_add=frozenset({' Nível de bolha'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Nível de bolha'}), items_add=frozenset({' Alicate de bico'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de bico', 'Pistola de cola quente'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de bico'}), items_add=frozenset({'Pistola de cola quente'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Pistola de cola quente'}), items_add=frozenset({' Alicate de bico'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Estilete', ' Alicate de corte'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de corte'}), items_add=frozenset({' Estilete'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Estilete'}), items_add=frozenset({' Alicate de corte'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de corte', 'Lâmina de serra tico-tico'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de corte'}), items_add=frozenset({'Lâmina de serra tico-tico'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Lâmina de serra tico-tico'}), items_add=frozenset({' Alicate de corte'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de crimpagem', ' Luvas de segurança'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de crimpagem'}), items_add=frozenset({' Luvas de segurança'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Luvas de segurança'}), items_add=frozenset({' Alicate de crimpagem'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Alicate de crimpagem', 'Sugador de solda'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de crimpagem'}), items_add=frozenset({'Sugador de solda'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Sugador de solda'}), items_add=frozenset({' Alicate de crimpagem'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de pressão', ' Tinta esmalte'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de pressão'}), items_add=frozenset({' Tinta esmalte'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Tinta esmalte'}), items_add=frozenset({' Alicate de pressão'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate de pressão', 'Martelo de unha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate de pressão'}), items_add=frozenset({'Martelo de unha'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Martelo de unha'}), items_add=frozenset({' Alicate de pressão'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Alicate universal', ' Chave de grifo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate universal'}), items_add=frozenset({' Chave de grifo'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({' Chave de grifo'}), items_add=frozenset({' Alicate universal'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Alicate universal', 'Martelo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicate universal'}), items_add=frozenset({'Martelo'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({'Martelo'}), items_add=frozenset({' Alicate universal'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Grampeador manual', ' Alicates de pressão'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicates de pressão'}), items_add=frozenset({' Grampeador manual'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Grampeador manual'}), items_add=frozenset({' Alicates de pressão'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Serra circular de bancada', ' Alicates de pressão'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Alicates de pressão'}), items_add=frozenset({'Serra circular de bancada'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Serra circular de bancada'}), items_add=frozenset({' Alicates de pressão'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Martelo', ' Arame'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arame'}), items_add=frozenset({' Martelo'}), confidence=1.0, lift=24.1)]),
#  RelationRecord(items=frozenset({' Serrote', ' Arame'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arame'}), items_add=frozenset({' Serrote'}), confidence=1.0, lift=48.2), OrderedStatistic(items_base=frozenset({' Serrote'}), items_add=frozenset({' Arame'}), confidence=0.2, lift=48.2)]),
#  RelationRecord(items=frozenset({'Prego', ' Arame'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arame'}), items_add=frozenset({'Prego'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Prego'}), items_add=frozenset({' Arame'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Arame recozido', ' Vergalhões'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arame recozido'}), items_add=frozenset({' Vergalhões'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Vergalhões'}), items_add=frozenset({' Arame recozido'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Lajes pré-moldadas', ' Arame recozido'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arame recozido'}), items_add=frozenset({'Lajes pré-moldadas'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Lajes pré-moldadas'}), items_add=frozenset({' Arame recozido'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Tintas para grade', ' Arames farpados'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arames farpados'}), items_add=frozenset({' Tintas para grade'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Tintas para grade'}), items_add=frozenset({' Arames farpados'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Arames farpados', 'Telas de proteção'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Arames farpados'}), items_add=frozenset({'Telas de proteção'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Telas de proteção'}), items_add=frozenset({' Arames farpados'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Argamassa', ' Areia'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({' Argamassa'}), confidence=0.25, lift=10.041666666666668), OrderedStatistic(items_base=frozenset({' Argamassa'}), items_add=frozenset({' Areia'}), confidence=0.33333333333333337, lift=10.041666666666668)]),
#  RelationRecord(items=frozenset({' Cimento', ' Areia'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({' Cimento'}), confidence=0.5, lift=24.1), OrderedStatistic(items_base=frozenset({' Cimento'}), items_add=frozenset({' Areia'}), confidence=0.8, lift=24.1)]),
#  RelationRecord(items=frozenset({' Tijolos', ' Areia'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({' Tijolos'}), confidence=0.375, lift=22.59375), OrderedStatistic(items_base=frozenset({' Tijolos'}), items_add=frozenset({' Areia'}), confidence=0.75, lift=22.59375)]),
#  RelationRecord(items=frozenset({' Vergalhão', ' Areia'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Vergalhão'}), items_add=frozenset({' Areia'}), confidence=1.0, lift=30.125)]),
#  RelationRecord(items=frozenset({'Argamassa', ' Areia'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({'Argamassa'}), confidence=0.375, lift=22.59375), OrderedStatistic(items_base=frozenset({'Argamassa'}), items_add=frozenset({' Areia'}), confidence=0.75, lift=22.59375)]),
#  RelationRecord(items=frozenset({'Cimento', ' Areia'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({'Cimento'}), confidence=0.25, lift=20.083333333333336), OrderedStatistic(items_base=frozenset({'Cimento'}), items_add=frozenset({' Areia'}), confidence=0.6666666666666667, lift=20.083333333333336)]),
#  RelationRecord(items=frozenset({'Telhas de cerâmica', ' Areia'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Telhas de cerâmica'}), items_add=frozenset({' Areia'}), confidence=0.2, lift=6.025)]),
#  RelationRecord(items=frozenset({'Tijolos', ' Areia'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia'}), items_add=frozenset({'Tijolos'}), confidence=0.25, lift=15.0625), OrderedStatistic(items_base=frozenset({'Tijolos'}), items_add=frozenset({' Areia'}), confidence=0.5, lift=15.0625)]),
#  RelationRecord(items=frozenset({' Areia lavada', ' Tijolos refratários'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia lavada'}), items_add=frozenset({' Tijolos refratários'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Tijolos refratários'}), items_add=frozenset({' Areia lavada'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Areia lavada', 'Saco de cimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Areia lavada'}), items_add=frozenset({'Saco de cimento'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Saco de cimento'}), items_add=frozenset({' Areia lavada'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Cimento', ' Argamassa'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa'}), items_add=frozenset({' Cimento'}), confidence=0.33333333333333337, lift=16.06666666666667), OrderedStatistic(items_base=frozenset({' Cimento'}), items_add=frozenset({' Argamassa'}), confidence=0.4, lift=16.06666666666667)]),
#  RelationRecord(items=frozenset({' Nivelador de piso', ' Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Nivelador de piso'}), items_add=frozenset({' Argamassa'}), confidence=0.5, lift=20.083333333333336)]),
#  RelationRecord(items=frozenset({' Rejunte', ' Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Rejunte'}), items_add=frozenset({' Argamassa'}), confidence=0.5, lift=20.083333333333336)]),
#  RelationRecord(items=frozenset({' Serrote', ' Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Serrote'}), items_add=frozenset({' Argamassa'}), confidence=0.2, lift=8.033333333333335)]),
#  RelationRecord(items=frozenset({' Tijolos', ' Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Tijolos'}), items_add=frozenset({' Argamassa'}), confidence=0.25, lift=10.041666666666668)]),
#  RelationRecord(items=frozenset({' Argamassa', 'Cimento'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa'}), items_add=frozenset({'Cimento'}), confidence=0.33333333333333337, lift=26.777777777777782), OrderedStatistic(items_base=frozenset({'Cimento'}), items_add=frozenset({' Argamassa'}), confidence=0.6666666666666667, lift=26.777777777777782)]),
#  RelationRecord(items=frozenset({'Porcelanato', ' Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Porcelanato'}), items_add=frozenset({' Argamassa'}), confidence=1.0, lift=40.16666666666667)]),
#  RelationRecord(items=frozenset({'Tijolos', ' Argamassa'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa'}), items_add=frozenset({'Tijolos'}), confidence=0.5, lift=30.125), OrderedStatistic(items_base=frozenset({'Tijolos'}), items_add=frozenset({' Argamassa'}), confidence=0.75, lift=30.125000000000004)]),
#  RelationRecord(items=frozenset({' Cal', ' Argamassa para revestimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=0.2, lift=6.025)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', ' Revestimento cerâmico'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa para revestimento'}), items_add=frozenset({' Revestimento cerâmico'}), confidence=0.375, lift=30.125000000000004), OrderedStatistic(items_base=frozenset({' Revestimento cerâmico'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=1.0, lift=30.125)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', ' Telhas de cerâmica'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa para revestimento'}), items_add=frozenset({' Telhas de cerâmica'}), confidence=0.5, lift=30.125), OrderedStatistic(items_base=frozenset({' Telhas de cerâmica'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=1.0, lift=30.125)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', 'Argamassa'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Argamassa'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', 'Cal'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa para revestimento'}), items_add=frozenset({'Cal'}), confidence=0.25, lift=12.05), OrderedStatistic(items_base=frozenset({'Cal'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=0.4, lift=12.05)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', 'Revestimento cerâmico'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa para revestimento'}), items_add=frozenset({'Revestimento cerâmico'}), confidence=0.25, lift=30.125), OrderedStatistic(items_base=frozenset({'Revestimento cerâmico'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=1.0, lift=30.125)]),
#  RelationRecord(items=frozenset({' Argamassa para revestimento', 'Telhas de cerâmica'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Argamassa para revestimento'}), items_add=frozenset({'Telhas de cerâmica'}), confidence=0.25, lift=12.05), OrderedStatistic(items_base=frozenset({'Telhas de cerâmica'}), items_add=frozenset({' Argamassa para revestimento'}), confidence=0.4, lift=12.05)]),
#  RelationRecord(items=frozenset({' Porta-toalhas', ' Armário de parede'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Armário de parede'}), items_add=frozenset({' Porta-toalhas'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Porta-toalhas'}), items_add=frozenset({' Armário de parede'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Espelho para banheiro', ' Armário de parede'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Armário de parede'}), items_add=frozenset({'Espelho para banheiro'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Espelho para banheiro'}), items_add=frozenset({' Armário de parede'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Torneiras', ' Armários de banheiro'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Armários de banheiro'}), items_add=frozenset({' Torneiras'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Torneiras'}), items_add=frozenset({' Armários de banheiro'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Pias de banheiro', ' Armários de banheiro'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Armários de banheiro'}), items_add=frozenset({'Pias de banheiro'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Pias de banheiro'}), items_add=frozenset({' Armários de banheiro'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Caixa acoplada', ' Assento sanitário'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Assento sanitário'}), items_add=frozenset({' Caixa acoplada'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Caixa acoplada'}), items_add=frozenset({' Assento sanitário'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Vaso sanitário', ' Assento sanitário'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Assento sanitário'}), items_add=frozenset({'Vaso sanitário'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Vaso sanitário'}), items_add=frozenset({' Assento sanitário'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Trilhos', ' Automatizadores'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Automatizadores'}), items_add=frozenset({' Trilhos'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Trilhos'}), items_add=frozenset({' Automatizadores'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Automatizadores', 'Portões de garagem'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Automatizadores'}), items_add=frozenset({'Portões de garagem'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Portões de garagem'}), items_add=frozenset({' Automatizadores'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Bandeja para pintura', ' Espátula'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bandeja para pintura'}), items_add=frozenset({' Espátula'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Espátula'}), items_add=frozenset({' Bandeja para pintura'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Bandeja para pintura', ' Pincel de cerdas'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bandeja para pintura'}), items_add=frozenset({' Pincel de cerdas'}), confidence=1.0, lift=60.25), OrderedStatistic(items_base=frozenset({' Pincel de cerdas'}), items_add=frozenset({' Bandeja para pintura'}), confidence=0.25, lift=60.25)]),
#  RelationRecord(items=frozenset({' Bandeja para pintura', 'Tinta esmalte'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bandeja para pintura'}), items_add=frozenset({'Tinta esmalte'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({'Tinta esmalte'}), items_add=frozenset({' Bandeja para pintura'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Lâmina de estilete', ' Bateria de furadeira'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bateria de furadeira'}), items_add=frozenset({' Lâmina de estilete'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Lâmina de estilete'}), items_add=frozenset({' Bateria de furadeira'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Pistola de cola quente', ' Bateria de furadeira'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bateria de furadeira'}), items_add=frozenset({'Pistola de cola quente'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Pistola de cola quente'}), items_add=frozenset({' Bateria de furadeira'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Bucha de nylon', ' Broca de aço rápido'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca de aço rápido'}), items_add=frozenset({' Bucha de nylon'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Bucha de nylon'}), items_add=frozenset({' Broca de aço rápido'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Broca de aço rápido', 'Parafuso'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca de aço rápido'}), items_add=frozenset({'Parafuso'}), confidence=1.0, lift=60.25), OrderedStatistic(items_base=frozenset({'Parafuso'}), items_add=frozenset({' Broca de aço rápido'}), confidence=0.25, lift=60.25)]),
#  RelationRecord(items=frozenset({' Broca helicoidal', ' Lubrificante multiuso'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca helicoidal'}), items_add=frozenset({' Lubrificante multiuso'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Lubrificante multiuso'}), items_add=frozenset({' Broca helicoidal'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Broca helicoidal', 'Rolo para pintura de textura'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca helicoidal'}), items_add=frozenset({'Rolo para pintura de textura'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Rolo para pintura de textura'}), items_add=frozenset({' Broca helicoidal'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Espelho decorativo', ' Broca para metal'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca para metal'}), items_add=frozenset({' Espelho decorativo'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Espelho decorativo'}), items_add=frozenset({' Broca para metal'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Broca para metal', 'Tinta epóxi'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Broca para metal'}), items_add=frozenset({'Tinta epóxi'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Tinta epóxi'}), items_add=frozenset({' Broca para metal'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Bucha', ' Chave Philips'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({' Bucha'}), confidence=0.2, lift=6.885714285714286)]),
#  RelationRecord(items=frozenset({' Bucha', ' Martelo'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha'}), items_add=frozenset({' Martelo'}), confidence=0.5714285714285714, lift=13.77142857142857), OrderedStatistic(items_base=frozenset({' Martelo'}), items_add=frozenset({' Bucha'}), confidence=0.4, lift=13.771428571428572)]),
#  RelationRecord(items=frozenset({' Bucha', ' Parafuso'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Parafuso'}), items_add=frozenset({' Bucha'}), confidence=0.25, lift=8.607142857142858)]),
#  RelationRecord(items=frozenset({' Serrote', ' Bucha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Serrote'}), items_add=frozenset({' Bucha'}), confidence=0.2, lift=6.885714285714286)]),
#  RelationRecord(items=frozenset({' Bucha', ' Trena'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Trena'}), items_add=frozenset({' Bucha'}), confidence=0.33333333333333337, lift=11.476190476190476)]),
#  RelationRecord(items=frozenset({' Bucha', 'Chave de fenda'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha'}), items_add=frozenset({'Chave de fenda'}), confidence=0.2857142857142857, lift=17.21428571428571), OrderedStatistic(items_base=frozenset({'Chave de fenda'}), items_add=frozenset({' Bucha'}), confidence=0.5, lift=17.214285714285715)]),
#  RelationRecord(items=frozenset({' Bucha', 'Martelo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Martelo'}), items_add=frozenset({' Bucha'}), confidence=0.33333333333333337, lift=11.476190476190476)]),
#  RelationRecord(items=frozenset({' Bucha', 'Parafuso'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha'}), items_add=frozenset({'Parafuso'}), confidence=0.42857142857142855, lift=25.82142857142857), OrderedStatistic(items_base=frozenset({'Parafuso'}), items_add=frozenset({' Bucha'}), confidence=0.75, lift=25.82142857142857)]),
#  RelationRecord(items=frozenset({' Bucha', 'Prego'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Prego'}), items_add=frozenset({' Bucha'}), confidence=0.5, lift=17.214285714285715)]),
#  RelationRecord(items=frozenset({' Chave inglesa', ' Bucha de fixação'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha de fixação'}), items_add=frozenset({' Chave inglesa'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Chave inglesa'}), items_add=frozenset({' Bucha de fixação'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Furadeira elétrica', ' Bucha de fixação'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha de fixação'}), items_add=frozenset({'Furadeira elétrica'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Furadeira elétrica'}), items_add=frozenset({' Bucha de fixação'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Bucha de nylon', 'Parafuso'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bucha de nylon'}), items_add=frozenset({'Parafuso'}), confidence=1.0, lift=60.25), OrderedStatistic(items_base=frozenset({'Parafuso'}), items_add=frozenset({' Bucha de nylon'}), confidence=0.25, lift=60.25)]),
#  RelationRecord(items=frozenset({' Serra copo', ' Buchas'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Buchas'}), items_add=frozenset({' Serra copo'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({' Serra copo'}), items_add=frozenset({' Buchas'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({'Parafusos', ' Buchas'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Buchas'}), items_add=frozenset({'Parafusos'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Parafusos'}), items_add=frozenset({' Buchas'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Buchas para parede', ' Suportes'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Buchas para parede'}), items_add=frozenset({' Suportes'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Suportes'}), items_add=frozenset({' Buchas para parede'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Buchas para parede', 'Prateleira'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Buchas para parede'}), items_add=frozenset({'Prateleira'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Prateleira'}), items_add=frozenset({' Buchas para parede'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Interruptores', ' Cabos para instalação elétrica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cabos para instalação elétrica'}), items_add=frozenset({' Interruptores'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Interruptores'}), items_add=frozenset({' Cabos para instalação elétrica'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Chuveiro elétrico', ' Cabos para instalação elétrica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cabos para instalação elétrica'}), items_add=frozenset({'Chuveiro elétrico'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Chuveiro elétrico'}), items_add=frozenset({' Cabos para instalação elétrica'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Caixa acoplada', 'Vaso sanitário'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Caixa acoplada'}), items_add=frozenset({'Vaso sanitário'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Vaso sanitário'}), items_add=frozenset({' Caixa acoplada'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Caixa de distribuição', ' Disjuntor'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Caixa de distribuição'}), items_add=frozenset({' Disjuntor'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Disjuntor'}), items_add=frozenset({' Caixa de distribuição'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Caixa de distribuição', 'Fio de cobre'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Caixa de distribuição'}), items_add=frozenset({'Fio de cobre'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Fio de cobre'}), items_add=frozenset({' Caixa de distribuição'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Caixa de ferramentas', ' Trena'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Caixa de ferramentas'}), items_add=frozenset({' Trena'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Trena'}), items_add=frozenset({' Caixa de ferramentas'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Caixa de ferramentas', 'Chave de fenda'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Caixa de ferramentas'}), items_add=frozenset({'Chave de fenda'}), confidence=1.0, lift=60.25), OrderedStatistic(items_base=frozenset({'Chave de fenda'}), items_add=frozenset({' Caixa de ferramentas'}), confidence=0.25, lift=60.25)]),
#  RelationRecord(items=frozenset({' Cal', ' Parafuso'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({' Parafuso'}), confidence=0.4, lift=24.1), OrderedStatistic(items_base=frozenset({' Parafuso'}), items_add=frozenset({' Cal'}), confidence=0.5, lift=24.1)]),
#  RelationRecord(items=frozenset({' Cal', ' Prego'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({' Prego'}), confidence=0.4, lift=19.28), OrderedStatistic(items_base=frozenset({' Prego'}), items_add=frozenset({' Cal'}), confidence=0.4, lift=19.28)]),
#  RelationRecord(items=frozenset({' Cal', ' Telhas de fibrocimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({' Telhas de fibrocimento'}), confidence=0.2, lift=12.05), OrderedStatistic(items_base=frozenset({' Telhas de fibrocimento'}), items_add=frozenset({' Cal'}), confidence=0.25, lift=12.05)]),
#  RelationRecord(items=frozenset({' Cal', 'Telhas de cerâmica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({'Telhas de cerâmica'}), confidence=0.2, lift=9.64), OrderedStatistic(items_base=frozenset({'Telhas de cerâmica'}), items_add=frozenset({' Cal'}), confidence=0.2, lift=9.64)]),
#  RelationRecord(items=frozenset({' Cal', 'Telhas de fibrocimento'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Cal'}), items_add=frozenset({'Telhas de fibrocimento'}), confidence=0.8, lift=32.13333333333334), OrderedStatistic(items_base=frozenset({'Telhas de fibrocimento'}), items_add=frozenset({' Cal'}), confidence=0.6666666666666667, lift=32.13333333333334)]),
#  RelationRecord(items=frozenset({' Ralo', ' Calha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Calha'}), items_add=frozenset({' Ralo'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Ralo'}), items_add=frozenset({' Calha'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Silicone', ' Calha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Calha'}), items_add=frozenset({' Silicone'}), confidence=1.0, lift=80.33333333333334), OrderedStatistic(items_base=frozenset({' Silicone'}), items_add=frozenset({' Calha'}), confidence=0.33333333333333337, lift=80.33333333333334)]),
#  RelationRecord(items=frozenset({' Calha', 'Telhas de cerâmica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Calha'}), items_add=frozenset({'Telhas de cerâmica'}), confidence=1.0, lift=48.2), OrderedStatistic(items_base=frozenset({'Telhas de cerâmica'}), items_add=frozenset({' Calha'}), confidence=0.2, lift=48.2)]),
#  RelationRecord(items=frozenset({' Catalisador', ' Rolo texturizado'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Catalisador'}), items_add=frozenset({' Rolo texturizado'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Rolo texturizado'}), items_add=frozenset({' Catalisador'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Catalisador', 'Tinta epóxi'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Catalisador'}), items_add=frozenset({'Tinta epóxi'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Tinta epóxi'}), items_add=frozenset({' Catalisador'}), confidence=0.5, lift=120.5)]),
#  RelationRecord(items=frozenset({' Chave de fenda', ' Chave Philips'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({' Chave de fenda'}), confidence=0.4, lift=24.1), OrderedStatistic(items_base=frozenset({' Chave de fenda'}), items_add=frozenset({' Chave Philips'}), confidence=0.5, lift=24.1)]),
#  RelationRecord(items=frozenset({' Lápis de pedreiro', ' Chave Philips'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({' Lápis de pedreiro'}), confidence=0.2, lift=48.2), OrderedStatistic(items_base=frozenset({' Lápis de pedreiro'}), items_add=frozenset({' Chave Philips'}), confidence=1.0, lift=48.2)]),
#  RelationRecord(items=frozenset({' Chave Philips', ' Martelo'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({' Martelo'}), confidence=0.4, lift=9.64), OrderedStatistic(items_base=frozenset({' Martelo'}), items_add=frozenset({' Chave Philips'}), confidence=0.2, lift=9.64)]),
#  RelationRecord(items=frozenset({'Bucha', ' Chave Philips'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({'Bucha'}), confidence=0.4, lift=24.1), OrderedStatistic(items_base=frozenset({'Bucha'}), items_add=frozenset({' Chave Philips'}), confidence=0.5, lift=24.1)]),
#  RelationRecord(items=frozenset({' Chave Philips', 'Martelo'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({'Martelo'}), confidence=0.4, lift=32.13333333333334), OrderedStatistic(items_base=frozenset({'Martelo'}), items_add=frozenset({' Chave Philips'}), confidence=0.6666666666666667, lift=32.13333333333334)]),
#  RelationRecord(items=frozenset({' Chave Philips', 'Tinta para piso epóxi'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave Philips'}), items_add=frozenset({'Tinta para piso epóxi'}), confidence=0.2, lift=48.2), OrderedStatistic(items_base=frozenset({'Tinta para piso epóxi'}), items_add=frozenset({' Chave Philips'}), confidence=1.0, lift=48.2)]),
#  RelationRecord(items=frozenset({' Nível de alumínio', ' Chave ajustável de corrente'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave ajustável de corrente'}), items_add=frozenset({' Nível de alumínio'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Nível de alumínio'}), items_add=frozenset({' Chave ajustável de corrente'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Fita de demarcação', ' Chave ajustável de corrente'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave ajustável de corrente'}), items_add=frozenset({'Fita de demarcação'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Fita de demarcação'}), items_add=frozenset({' Chave ajustável de corrente'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de boca', ' Disco de corte'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de boca'}), items_add=frozenset({' Disco de corte'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Disco de corte'}), items_add=frozenset({' Chave de boca'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de boca', 'Martelo de pena'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de boca'}), items_add=frozenset({'Martelo de pena'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Martelo de pena'}), items_add=frozenset({' Chave de boca'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de cano', ' Fita zebrada de segurança'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de cano'}), items_add=frozenset({' Fita zebrada de segurança'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Fita zebrada de segurança'}), items_add=frozenset({' Chave de cano'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de cano', 'Fita VHB'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de cano'}), items_add=frozenset({'Fita VHB'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Fita VHB'}), items_add=frozenset({' Chave de cano'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de catraca', ' Óculos de proteção'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de catraca'}), items_add=frozenset({' Óculos de proteção'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Óculos de proteção'}), items_add=frozenset({' Chave de catraca'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Fita isolante', ' Chave de catraca'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de catraca'}), items_add=frozenset({'Fita isolante'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'Fita isolante'}), items_add=frozenset({' Chave de catraca'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({' Chave de fenda', ' Martelo'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda'}), items_add=frozenset({' Martelo'}), confidence=0.5, lift=12.05), OrderedStatistic(items_base=frozenset({' Martelo'}), items_add=frozenset({' Chave de fenda'}), confidence=0.2, lift=12.05)]),
#  RelationRecord(items=frozenset({' Chave de fenda', ' Prego'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda'}), items_add=frozenset({' Prego'}), confidence=0.25, lift=12.05), OrderedStatistic(items_base=frozenset({' Prego'}), items_add=frozenset({' Chave de fenda'}), confidence=0.2, lift=12.05)]),
#  RelationRecord(items=frozenset({' Chave de fenda', 'Bucha'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda'}), items_add=frozenset({'Bucha'}), confidence=0.75, lift=45.1875), OrderedStatistic(items_base=frozenset({'Bucha'}), items_add=frozenset({' Chave de fenda'}), confidence=0.75, lift=45.1875)]),
#  RelationRecord(items=frozenset({' Chave de fenda', 'Martelo'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda'}), items_add=frozenset({'Martelo'}), confidence=0.25, lift=20.083333333333336), OrderedStatistic(items_base=frozenset({'Martelo'}), items_add=frozenset({' Chave de fenda'}), confidence=0.33333333333333337, lift=20.083333333333336)]),
#  RelationRecord(items=frozenset({' Kit de chaves de precisão', ' Chave de fenda elétrica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda elétrica'}), items_add=frozenset({' Kit de chaves de precisão'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({' Kit de chaves de precisão'}), items_add=frozenset({' Chave de fenda elétrica'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'Tinta para piso', ' Chave de fenda elétrica'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Chave de fenda elétrica'}), items_add=frozenset({'Tinta para piso'}), confidence=1.0, lift=120.5), OrderedStatistic(items_base=frozenset({'Tinta para piso'}), items_add=frozenset({' Chave de fenda elétrica'}), confidence=0.5, lift=120.5)]),
# ...
#  RelationRecord(items=frozenset({'Níveldebolha', 'Chavedegrifo'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedegrifo'}), items_add=frozenset({'Níveldebolha'}), confidence=0.42857142857142855, lift=12.910714285714285), OrderedStatistic(items_base=frozenset({'Níveldebolha'}), items_add=frozenset({'Chavedegrifo'}), confidence=0.375, lift=12.910714285714285)]),
#  RelationRecord(items=frozenset({'Pistoladecolaquente', 'Chavedegrifo'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedegrifo'}), items_add=frozenset({'Pistoladecolaquente'}), confidence=0.2857142857142857, lift=8.607142857142856), OrderedStatistic(items_base=frozenset({'Pistoladecolaquente'}), items_add=frozenset({'Chavedegrifo'}), confidence=0.25, lift=8.607142857142858)]),
#  RelationRecord(items=frozenset({'Chavedegrifo', 'Serradefita'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Serradefita'}), items_add=frozenset({'Chavedegrifo'}), confidence=0.2, lift=6.885714285714286)]),
#  RelationRecord(items=frozenset({'Furadeiraelétrica', 'Chavedeteste'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedeteste'}), items_add=frozenset({'Furadeiraelétrica'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Furadeiraelétrica'}), items_add=frozenset({'Chavedeteste'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({"Lixad'água", 'Chavedeteste'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedeteste'}), items_add=frozenset({"Lixad'água"}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({"Lixad'água"}), items_add=frozenset({'Chavedeteste'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Martelodepena', 'Chavedeteste'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedeteste'}), items_add=frozenset({'Martelodepena'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Martelodepena'}), items_add=frozenset({'Chavedeteste'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Tintaacrílica', 'Chavedeteste'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedeteste'}), items_add=frozenset({'Tintaacrílica'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Tintaacrílica'}), items_add=frozenset({'Chavedeteste'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Trenaretrátil', 'Chavedeteste'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chavedeteste'}), items_add=frozenset({'Trenaretrátil'}), confidence=0.375, lift=10.041666666666666), OrderedStatistic(items_base=frozenset({'Trenaretrátil'}), items_add=frozenset({'Chavedeteste'}), confidence=0.3333333333333333, lift=10.041666666666666)]),
#  RelationRecord(items=frozenset({'Martelodeunha', 'Chaveinglesa'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chaveinglesa'}), items_add=frozenset({'Martelodeunha'}), confidence=0.25, lift=10.041666666666668), OrderedStatistic(items_base=frozenset({'Martelodeunha'}), items_add=frozenset({'Chaveinglesa'}), confidence=0.33333333333333337, lift=10.041666666666668)]),
#  RelationRecord(items=frozenset({'Tintaacrílica', 'Chaveinglesa'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Chaveinglesa'}), items_add=frozenset({'Tintaacrílica'}), confidence=0.375, lift=11.296875), OrderedStatistic(items_base=frozenset({'Tintaacrílica'}), items_add=frozenset({'Chaveinglesa'}), confidence=0.375, lift=11.296875)]),
#  RelationRecord(items=frozenset({'Discodecorte', 'Espátuladeaço'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Discodecorte'}), items_add=frozenset({'Espátuladeaço'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Espátuladeaço'}), items_add=frozenset({'Discodecorte'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Pistoladecolaquente', 'Discodecorte'}), support=0.024896265560165973, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Discodecorte'}), items_add=frozenset({'Pistoladecolaquente'}), confidence=0.75, lift=22.59375), OrderedStatistic(items_base=frozenset({'Pistoladecolaquente'}), items_add=frozenset({'Discodecorte'}), confidence=0.75, lift=22.59375)]),
#  RelationRecord(items=frozenset({"Lixad'água", 'Espátuladeaço'}), support=0.029045643153526972, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Espátuladeaço'}), items_add=frozenset({"Lixad'água"}), confidence=0.875, lift=26.359375), OrderedStatistic(items_base=frozenset({"Lixad'água"}), items_add=frozenset({'Espátuladeaço'}), confidence=0.875, lift=26.359375)]),
#  RelationRecord(items=frozenset({'Martelodepena', 'Espátuladeaço'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Espátuladeaço'}), items_add=frozenset({'Martelodepena'}), confidence=0.375, lift=11.296875), OrderedStatistic(items_base=frozenset({'Martelodepena'}), items_add=frozenset({'Espátuladeaço'}), confidence=0.375, lift=11.296875)]),
#  RelationRecord(items=frozenset({'Martelodeunha', 'Estilete'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Estilete'}), items_add=frozenset({'Martelodeunha'}), confidence=0.42857142857142855, lift=17.214285714285715), OrderedStatistic(items_base=frozenset({'Martelodeunha'}), items_add=frozenset({'Estilete'}), confidence=0.5, lift=17.214285714285715)]),
#  RelationRecord(items=frozenset({'Níveldebolha', 'Estilete'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Estilete'}), items_add=frozenset({'Níveldebolha'}), confidence=0.2857142857142857, lift=8.607142857142856), OrderedStatistic(items_base=frozenset({'Níveldebolha'}), items_add=frozenset({'Estilete'}), confidence=0.25, lift=8.607142857142858)]),
#  RelationRecord(items=frozenset({'KitdechavesAllen', 'Fitaadesiva'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fitaadesiva'}), items_add=frozenset({'KitdechavesAllen'}), confidence=0.25, lift=8.607142857142858), OrderedStatistic(items_base=frozenset({'KitdechavesAllen'}), items_add=frozenset({'Fitaadesiva'}), confidence=0.2857142857142857, lift=8.607142857142856)]),
#  RelationRecord(items=frozenset({'Parafusoautoatarraxante', 'Fitaadesiva'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fitaadesiva'}), items_add=frozenset({'Parafusoautoatarraxante'}), confidence=0.5, lift=15.0625), OrderedStatistic(items_base=frozenset({'Parafusoautoatarraxante'}), items_add=frozenset({'Fitaadesiva'}), confidence=0.5, lift=15.0625)]),
#  RelationRecord(items=frozenset({'Tintaesmalte', 'Fitaadesiva'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Fitaadesiva'}), items_add=frozenset({'Tintaesmalte'}), confidence=0.25, lift=12.05), OrderedStatistic(items_base=frozenset({'Tintaesmalte'}), items_add=frozenset({'Fitaadesiva'}), confidence=0.4, lift=12.05)]),
#  RelationRecord(items=frozenset({'Furadeiraelétrica', 'KitdechavesAllen'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Furadeiraelétrica'}), items_add=frozenset({'KitdechavesAllen'}), confidence=0.375, lift=12.910714285714285), OrderedStatistic(items_base=frozenset({'KitdechavesAllen'}), items_add=frozenset({'Furadeiraelétrica'}), confidence=0.42857142857142855, lift=12.910714285714285)]),
#  RelationRecord(items=frozenset({'Martelodepena', 'Furadeiraelétrica'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Furadeiraelétrica'}), items_add=frozenset({'Martelodepena'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Martelodepena'}), items_add=frozenset({'Furadeiraelétrica'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Parafusoautoatarraxante', 'Furadeiraelétrica'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Furadeiraelétrica'}), items_add=frozenset({'Parafusoautoatarraxante'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Parafusoautoatarraxante'}), items_add=frozenset({'Furadeiraelétrica'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Trenaretrátil', 'Furadeiraelétrica'}), support=0.02074688796680498, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Furadeiraelétrica'}), items_add=frozenset({'Trenaretrátil'}), confidence=0.625, lift=16.73611111111111), OrderedStatistic(items_base=frozenset({'Trenaretrátil'}), items_add=frozenset({'Furadeiraelétrica'}), confidence=0.5555555555555556, lift=16.73611111111111)]),
#  RelationRecord(items=frozenset({'argamassa', 'Janelas de alumínio'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Janelas de alumínio'}), items_add=frozenset({'argamassa'}), confidence=0.5, lift=120.5), OrderedStatistic(items_base=frozenset({'argamassa'}), items_add=frozenset({'Janelas de alumínio'}), confidence=1.0, lift=120.5)]),
#  RelationRecord(items=frozenset({'cal', 'Janelas de alumínio'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Janelas de alumínio'}), items_add=frozenset({'cal'}), confidence=0.5, lift=120.5), OrderedStatistic(items_base=frozenset({'cal'}), items_add=frozenset({'Janelas de alumínio'}), confidence=1.0, lift=120.5)]),
#  RelationRecord(items=frozenset({'Janelas de alumínio', 'cimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Janelas de alumínio'}), items_add=frozenset({'cimento'}), confidence=0.5, lift=120.5), OrderedStatistic(items_base=frozenset({'cimento'}), items_add=frozenset({'Janelas de alumínio'}), confidence=1.0, lift=120.5)]),
#  RelationRecord(items=frozenset({'Parafusoautoatarraxante', 'KitdechavesAllen'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'KitdechavesAllen'}), items_add=frozenset({'Parafusoautoatarraxante'}), confidence=0.42857142857142855, lift=12.910714285714285), OrderedStatistic(items_base=frozenset({'Parafusoautoatarraxante'}), items_add=frozenset({'KitdechavesAllen'}), confidence=0.375, lift=12.910714285714285)]),
#  RelationRecord(items=frozenset({'KitdechavesAllen', 'Serradefita'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Serradefita'}), items_add=frozenset({'KitdechavesAllen'}), confidence=0.2, lift=6.885714285714286)]),
#  RelationRecord(items=frozenset({'Trenaretrátil', 'KitdechavesAllen'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'KitdechavesAllen'}), items_add=frozenset({'Trenaretrátil'}), confidence=0.2857142857142857, lift=7.65079365079365), OrderedStatistic(items_base=frozenset({'Trenaretrátil'}), items_add=frozenset({'KitdechavesAllen'}), confidence=0.22222222222222224, lift=7.650793650793651)]),
#  RelationRecord(items=frozenset({"Lixad'água", 'Martelodepena'}), support=0.016597510373443983, ordered_statistics=[OrderedStatistic(items_base=frozenset({"Lixad'água"}), items_add=frozenset({'Martelodepena'}), confidence=0.5, lift=15.0625), OrderedStatistic(items_base=frozenset({'Martelodepena'}), items_add=frozenset({"Lixad'água"}), confidence=0.5, lift=15.0625)]),
#  RelationRecord(items=frozenset({'Serracircular', 'Martelodeborracha'}), support=0.012448132780082987, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Martelodeborracha'}), items_add=frozenset({'Serracircular'}), confidence=0.75, lift=25.82142857142857), OrderedStatistic(items_base=frozenset({'Serracircular'}), items_add=frozenset({'Martelodeborracha'}), confidence=0.42857142857142855, lift=25.82142857142857)]),
#  RelationRecord(items=frozenset({'Tintaspray', 'Martelodeborracha'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Martelodeborracha'}), items_add=frozenset({'Tintaspray'}), confidence=0.25, lift=8.607142857142858)]),
#  RelationRecord(items=frozenset({'Tintaacrílica', 'Martelodepena'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Martelodepena'}), items_add=frozenset({'Tintaacrílica'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Tintaacrílica'}), items_add=frozenset({'Martelodepena'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Níveldebolha', 'Pistoladecolaquente'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Níveldebolha'}), items_add=frozenset({'Pistoladecolaquente'}), confidence=0.25, lift=7.53125), OrderedStatistic(items_base=frozenset({'Pistoladecolaquente'}), items_add=frozenset({'Níveldebolha'}), confidence=0.25, lift=7.53125)]),
#  RelationRecord(items=frozenset({'Níveldebolha', 'Serradefita'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Níveldebolha'}), items_add=frozenset({'Serradefita'}), confidence=0.25, lift=12.05), OrderedStatistic(items_base=frozenset({'Serradefita'}), items_add=frozenset({'Níveldebolha'}), confidence=0.4, lift=12.05)]),
#  RelationRecord(items=frozenset({'Parafusoautoatarraxante', 'Serradefita'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Serradefita'}), items_add=frozenset({'Parafusoautoatarraxante'}), confidence=0.2, lift=6.025)]),
#  RelationRecord(items=frozenset({'Rolodeespuma', 'Tintaesmalte'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Tintaesmalte'}), items_add=frozenset({'Rolodeespuma'}), confidence=0.2, lift=6.025)]),
#  RelationRecord(items=frozenset({'Rolodeespuma', 'Tintaspray'}), support=0.024896265560165973, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Rolodeespuma'}), items_add=frozenset({'Tintaspray'}), confidence=0.75, lift=25.82142857142857), OrderedStatistic(items_base=frozenset({'Tintaspray'}), items_add=frozenset({'Rolodeespuma'}), confidence=0.8571428571428571, lift=25.82142857142857)]),
#  RelationRecord(items=frozenset({'Serracircular', 'Tintaspray'}), support=0.008298755186721992, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Serracircular'}), items_add=frozenset({'Tintaspray'}), confidence=0.2857142857142857, lift=9.83673469387755), OrderedStatistic(items_base=frozenset({'Tintaspray'}), items_add=frozenset({'Serracircular'}), confidence=0.2857142857142857, lift=9.83673469387755)]),
#  RelationRecord(items=frozenset({'argamassa', 'cal'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'argamassa'}), items_add=frozenset({'cal'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'cal'}), items_add=frozenset({'argamassa'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'argamassa', 'cimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'argamassa'}), items_add=frozenset({'cimento'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'cimento'}), items_add=frozenset({'argamassa'}), confidence=1.0, lift=241.0)]),
#  RelationRecord(items=frozenset({'cal', 'cimento'}), support=0.004149377593360996, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cal'}), items_add=frozenset({'cimento'}), confidence=1.0, lift=241.0), OrderedStatistic(items_base=frozenset({'cimento'}), items_add=frozenset({'cal'}), confidence=1.0, lift=241.0)])]

# %% [markdown]
# ### Organizando os resultados em DataFrame

# %%
def inspect(resultado):
    lado_esquerdo         = [resultado[2][0][0] for resultado in resultado]
    lado_direito         = [resultado[2][0][1] for resultado in resultado]
    apoio   = [resultado[1] for resultado in resultado]
    confiaça = [resultado[2][0][2] for resultado in resultado]
    lifts       = [resultado[2][0][3] for resultado in resultado] #Um lift maior que 1 indica que a ocorrência do lhs aumenta a probabilidade de ocorrência do rhs, o que sugere uma associação positiva entre os itens. Um lift igual a 1 indica que a ocorrência do lhs e do rhs é independente. Um lift menor que 1 indica que a ocorrência do lhs diminui a probabilidade de ocorrência do rhs, o que sugere uma associação negativa entre os itens.
    return list(zip(lado_esquerdo, lado_direito, apoio, confiaça, lifts))
resultadoDataFrame = pd.DataFrame(inspect(resultado), columns = ['Lado esquerdo', 'Lado direito', 'Apoio', 'Confiança', 'Lift'])

# %% [markdown]
# ### Mostrando os resultados sem ordenação

# %%
resultadoDataFrame
# Out:
#                Lado esquerdo       Lado direito     Apoio  Confiança  \
# 0    ( Abraçadeira metálica)  ( Chave de grifo)  0.004149   1.000000
# 1    ( Abraçadeira metálica)    (Serra de fita)  0.004149   1.000000
# 2    ( Adesivo para azulejo)        ( Espátula)  0.004149   1.000000
# 3    ( Adesivo para azulejo)   ( Revestimentos)  0.004149   1.000000
# 4    ( Adesivo para azulejo)            (Pisos)  0.004149   1.000000
# ..                       ...                ...       ...        ...
# 556           (Rolodeespuma)       (Tintaspray)  0.024896   0.750000
# 557          (Serracircular)       (Tintaspray)  0.008299   0.285714
# 558              (argamassa)              (cal)  0.004149   1.000000
# 559              (argamassa)          (cimento)  0.004149   1.000000
# 560                    (cal)          (cimento)  0.004149   1.000000
#
#            Lift
# 0    120.500000
# 1    241.000000
# 2     80.333333
# 3    241.000000
# 4    241.000000
# ..          ...
# 556   25.821429
# 557    9.836735
# 558  241.000000
# 559  241.000000
# 560  241.000000
#
# [561 rows x 5 columns]

# %% [markdown]
# ### Mostrando os resultados ordenados pelo lift

# %%
resultadoDataFrame.nlargest(n = 20, columns = 'Confiança')
# Out:
#                 Lado esquerdo                 Lado direito     Apoio  \
# 0     ( Abraçadeira metálica)            ( Chave de grifo)  0.004149
# 1     ( Abraçadeira metálica)              (Serra de fita)  0.004149
# 2     ( Adesivo para azulejo)                  ( Espátula)  0.004149
# 3     ( Adesivo para azulejo)             ( Revestimentos)  0.004149
# 4     ( Adesivo para azulejo)                      (Pisos)  0.004149
# 5                  ( Alicate)                   ( Martelo)  0.004149
# 6                  ( Alicate)                     ( Trena)  0.004149
# 7                  ( Alicate)             (Chave de fenda)  0.004149
# 8      ( Alicate amperímetro)              ( Saco de lixo)  0.004149
# 9      ( Alicate amperímetro)              (Serra de arco)  0.004149
# 10  ( Alicate corte diagonal)          ( Espuma expansiva)  0.004149
# 11  ( Alicate corte diagonal)         (Tinta emborrachada)  0.004149
# 12         ( Alicate de bico)            ( Nível de bolha)  0.004149
# 13         ( Alicate de bico)     (Pistola de cola quente)  0.004149
# 14        ( Alicate de corte)                  ( Estilete)  0.004149
# 15        ( Alicate de corte)  (Lâmina de serra tico-tico)  0.004149
# 16    ( Alicate de crimpagem)        ( Luvas de segurança)  0.004149
# 17    ( Alicate de crimpagem)           (Sugador de solda)  0.004149
# 18      ( Alicate de pressão)             ( Tinta esmalte)  0.004149
# 19      ( Alicate de pressão)            (Martelo de unha)  0.004149
#
#     Confiança        Lift
# 0         1.0  120.500000
# 1         1.0  241.000000
# 2         1.0   80.333333
# 3         1.0  241.000000
# 4         1.0  241.000000
# 5         1.0   24.100000
# 6         1.0   80.333333
# 7         1.0   60.250000
# 8         1.0  241.000000
# 9         1.0  241.000000
# 10        1.0  241.000000
# 11        1.0  241.000000
# 12        1.0  241.000000
# 13        1.0  120.500000
# 14        1.0  241.000000
# 15        1.0  241.000000
# 16        1.0   80.333333
# 17        1.0  241.000000
# 18        1.0  241.000000
# 19        1.0  241.000000
